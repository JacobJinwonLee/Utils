# %%
import pandas as pd
import pandas_datareader.data as web
import datetime
import backtrader as bt
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import pyfolio as pf
import quantstats
plt.rcParams["figure.figsize"] = (10, 6) # (w, h)
import sys
import time
import sqlite3
from scipy.stats import rankdata
from scipy.stats import stats
from scipy.optimize import minimize

# %% [markdown]
# 미국 상장 ETF들의 일간 가격 정보를 다운로드 받을 것입니다. ETF Ticker는 나스닥의 ftp(ftp.nasdaqtrader.com/SymbolDirectory)에서 가져왔고, 가공했습니다. 상장된 지 가장 오래된 ETF인 SPY(SPDR S&P 500 ETF Trust)가 1993년 1월 22일 상장이므로, 그 시점부터 시작하겠습니다.

# %%
nasdaqlisted = pd.read_excel('nasdaqlisted.xlsx', sheet_name='nasdaqlistedetf', encoding='utf-8')
otherlisted = pd.read_excel('otherlisted.xlsx', sheet_name='otherlistedetf', encoding='utf-8')

# %%
nasdaqlisted.head()
# Out:
#   Symbol                                      Security Name Market Category  \
# 0   AAXJ  iShares MSCI All Country Asia ex Japan Index Fund               G
# 1   ACWI                       iShares MSCI ACWI Index Fund               G
# 2   ACWX                 iShares MSCI ACWI ex US Index Fund               G
# 3   ADRE   Invesco BLDRS Emerging Markets 50 ADR Index Fund               G
# 4   AGZD  WisdomTree Interest Rate Hedged U.S. Aggregate...               G
#
#   Test Issue Financial Status  Round Lot Size ETF NextShares
# 0          N                N             100   Y          N
# 1          N                N             100   Y          N
# 2          N                N             100   Y          N
# 3          N                N             100   Y          N
# 4          N                N             100   Y          N

# %%
len(nasdaqlisted)
# Out:
# 407

# %%
otherlisted.head()
# Out:
#   ACT Symbol                                      Security Name Exchange  \
# 0        AAA  Listed Funds Trust AAF First Priority CLO Bond...        P
# 1       AAAU             Goldman Sachs Physical Gold ETF Shares        P
# 2       AADR                AdvisorShares Dorsey Wright ADR ETF        P
# 3       ABEQ                         Absolute Core Strategy ETF        P
# 4       ACES                              ALPS Clean Energy ETF        Z
#
#   CQS Symbol ETF  Round Lot Size Test Issue NASDAQ Symbol
# 0        AAA   Y             100          N           AAA
# 1       AAAU   Y             100          N          AAAU
# 2       AADR   Y             100          N          AADR
# 3       ABEQ   Y             100          N          ABEQ
# 4       ACES   Y             100          N          ACES

# %%
len(otherlisted)
# Out:
# 1940

# %%
ticker_list = list(nasdaqlisted['Symbol']) + list(otherlisted['NASDAQ Symbol'])
ticker_list[0:5]
# Out:
# ['AAXJ', 'ACWI', 'ACWX', 'ADRE', 'AGZD']

# %%
len(ticker_list)
# Out:
# 2347

# %% [markdown]
# Yahoo Finance에서 OHLCV 데이터를 가져옵니다. USListedETFPrice.db 이름의 sqlite 파일에 저장되고, ticker 이름으로 된 테이블에 데이터가 들어갑니다.

# %%
def OHLCV_Download(ticker, start, end):
    df = web.DataReader(ticker, 'yahoo', start, end)
    con = sqlite3.connect('USListedETFPrice.db')
    df.to_sql(ticker, con, if_exists='append')
    con.close()

# %% [markdown]
# 차단 방지를 위해 50개 ticker 호출마다 10초씩 멈춥니다.

# %%
i = 1
for ticker in ticker_list:
    try:
        print((i, ticker))

        OHLCV_Download(ticker, '1993-01-22', '2021-02-19')

        i += 1

        if i % 50 == 0:
            time.sleep(10)
        
    except:
        print((i, ticker, 'Error Occurred'))
        OHLCV_Download(ticker, '1993-01-22', '2021-02-19')
# Out:
# (1, 'AAXJ')
# (2, 'ACWI')
# (3, 'ACWX')
# (4, 'ADRE')
# (5, 'AGZD')
# (6, 'AIA')
# (7, 'AIQ')
# (8, 'AIRR')
# (9, 'ALTY')
# (10, 'AMCA')
# (11, 'ANGL')
# (12, 'ASET')
# (13, 'BBH')
# (14, 'BFIT')
# (15, 'BGRN')
# (16, 'BIB')
# (17, 'BICK')
# (18, 'BIS')
# (19, 'BJK')
# (20, 'BLCN')
# (21, 'BND')
# (22, 'BNDW')
# (23, 'BNDX')
# (24, 'BOTZ')
# (25, 'BSAE')
# (26, 'BSBE')
# (27, 'BSCE')
# (28, 'BSCL')
# (29, 'BSCM')
# (30, 'BSCN')
# (31, 'BSCO')
# (32, 'BSCP')
# (33, 'BSCQ')
# (34, 'BSCR')
# (35, 'BSCS')
# (36, 'BSCT')
# (37, 'BSCU')
# (38, 'BSDE')
# (39, 'BSJL')
# (40, 'BSJM')
# (41, 'BSJN')
# (42, 'BSJO')
# (43, 'BSJP')
# (44, 'BSJQ')
# (45, 'BSJR')
# (46, 'BSJS')
# (47, 'BSML')
# (48, 'BSMM')
# (49, 'BSMN')
# (50, 'BSMO')
# (51, 'BSMP')
# (52, 'BSMQ')
# (53, 'BSMR')
# (54, 'BSMS')
# (55, 'BSMT')
# (56, 'BSMU')
# (57, 'BTEC')
# (58, 'BUG')
# (59, 'CACG')
# (60, 'CARZ')
# (61, 'CATH')
# (62, 'CDC')
# (63, 'CDL')
# (64, 'CEFA')
# (65, 'CEY')
# (66, 'CEZ')
# (67, 'CFA')
# (68, 'CFO')
# (69, 'CHB')
# (70, 'CHNA')
# (71, 'CIBR')
# (72, 'CID')
# (73, 'CIL')
# (74, 'CIZ')
# (75, 'CLOU')
# (76, 'CLRG')
# (77, 'CNCR')
# (78, 'COMT')
# (79, 'CSA')
# (80, 'CSB')
# (81, 'CSF')
# (82, 'CSML')
# (83, 'CTEC')
# (84, 'CXSE')
# (85, 'DALI')
# (86, 'DAX')
# (87, 'DDIV')
# (88, 'DEMZ')
# (89, 'DFNL')
# (90, 'DGRE')
# (91, 'DGRS')
# (92, 'DGRW')
# (93, 'DINT')
# (94, 'DMXF')
# (95, 'DRIV')
# (96, 'DUSA')
# (97, 'DVLU')
# (98, 'DVOL')
# (99, 'DVY')
# (100, 'DWAS')
# (101, 'DWAT')
# (102, 'DWAW')
# (103, 'DWCR')
# (104, 'DWEQ')
# (105, 'DWFI')
# (106, 'DWLD')
# (107, 'DWMC')
# (108, 'DWPP')
# (109, 'DWSH')
# (110, 'DWUS')
# (111, 'DXGE')
# (112, 'DXJS')
# (113, 'EBIZ')
# (114, 'ECOW')
# (115, 'EDOC')
# (116, 'EDUT')
# (117, 'EEMA')
# (118, 'EFAS')
# (119, 'EMB')
# (120, 'EMCB')
# (121, 'EMIF')
# (122, 'EMXC')
# (123, 'EMXF')
# (124, 'ENZL')
# (125, 'EQRR')
# (126, 'ESGD')
# (127, 'ESGE')
# (128, 'ESGU')
# (129, 'ESPO')
# (130, 'EUFN')
# (131, 'EWEB')
# (132, 'EWJE')
# (133, 'EWJV')
# (134, 'EWZS')
# (135, 'FAAR')
# (136, 'FAB')
# (137, 'FAD')
# (138, 'FALN')
# (139, 'FBZ')
# (140, 'FCA')
# (141, 'FCAL')
# (142, 'FCEF')
# (143, 'FCVT')
# (144, 'FDIV')
# (145, 'FDNI')
# (146, 'FDT')
# (147, 'FDTS')
# (148, 'FEM')
# (149, 'FEMB')
# (150, 'FEMS')
# (151, 'FEP')
# (152, 'FEUZ')
# (153, 'FEX')
# (154, 'FGM')
# (155, 'FICS')
# (156, 'FID')
# (157, 'FINX')
# (158, 'FIXD')
# (159, 'FJP')
# (160, 'FKU')
# (161, 'FLN')
# (162, 'FMB')
# (163, 'FMHI')
# (164, 'FNK')
# (165, 'FNX')
# (166, 'FNY')
# (167, 'FPA')
# (168, 'FPXE')
# (169, 'FPXI')
# (170, 'FSZ')
# (171, 'FTA')
# (172, 'FTAG')
# (173, 'FTC')
# (174, 'FTCS')
# (175, 'FTGC')
# (176, 'FTHI')
# (177, 'FTLB')
# (178, 'FTRI')
# (179, 'FTSL')
# (180, 'FTSM')
# (181, 'FTXD')
# (182, 'FTXG')
# (183, 'FTXH')
# (184, 'FTXL')
# (185, 'FTXN')
# (186, 'FTXO')
# (187, 'FTXR')
# (188, 'FV')
# (189, 'FVC')
# (190, 'FYC')
# (191, 'FYT')
# (192, 'FYX')
# (193, 'GENY')
# (194, 'GIGE')
# (195, 'GNMA')
# (196, 'GNOM')
# (197, 'GRID')
# (198, 'GXTG')
# (199, 'HERD')
# (200, 'HERO')
# (201, 'HEWG')
# (202, 'HLAL')
# (203, 'HNDL')
# (204, 'HYLS')
# (205, 'HYXF')
# (206, 'HYZD')
# (207, 'IBB')
# (208, 'IBBJ')
# (209, 'IBTA')
# (210, 'IBTB')
# (211, 'IBTD')
# (212, 'IBTE')
# (213, 'IBTF')
# (214, 'IBTG')
# (215, 'IBTH')
# (216, 'IBTI')
# (217, 'IBTJ')
# (218, 'IBTK')
# (219, 'ICLN')
# (220, 'IDLB')
# (221, 'IEF')
# (222, 'IEI')
# (223, 'IEUS')
# (224, 'IFGL')
# (225, 'IFV')
# (226, 'IGF')
# (227, 'IGIB')
# (228, 'IGOV')
# (229, 'IGSB')
# (230, 'IHYF')
# (231, 'IJT')
# (232, 'INDY')
# (233, 'INFR')
# (234, 'IPKW')
# (235, 'ISDX')
# (236, 'ISEM')
# (237, 'ISHG')
# (238, 'ISTB')
# (239, 'IUS')
# (240, 'IUSB')
# (241, 'IUSG')
# (242, 'IUSS')
# (243, 'IUSV')
# (244, 'IXUS')
# (245, 'JKI')
# (246, 'JOET')
# (247, 'JSMD')
# (248, 'JSML')
# (249, 'KBWB')
# (250, 'KBWD')
# (251, 'KBWP')
# (252, 'KBWR')
# (253, 'KBWY')
# (254, 'KRMA')
# (255, 'LDEM')
# (256, 'LDSF')
# (257, 'LEGR')
# (258, 'LMBS')
# (259, 'LNGR')
# (260, 'LRGE')
# (261, 'LVHD')
# (262, 'MBB')
# (263, 'MCEF')
# (264, 'MCHI')
# (265, 'MDIV')
# (266, 'MILN')
# (267, 'NFTY')
# (268, 'NXTG')
# (269, 'OLD')
# (270, 'ONEQ')
# (271, 'PDBC')
# (272, 'PDEV')
# (273, 'PDP')
# (274, 'PEY')
# (275, 'PEZ')
# (276, 'PFF')
# (277, 'PFI')
# (278, 'PFM')
# (279, 'PGJ')
# (280, 'PHO')
# (281, 'PID')
# (282, 'PIE')
# (283, 'PIO')
# (284, 'PIZ')
# (285, 'PKW')
# (286, 'PLW')
# (287, 'PNQI')
# (288, 'POTX')
# (289, 'PPH')
# (290, 'PRFZ')
# (291, 'PRN')
# (292, 'PSC')
# (293, 'PSCC')
# (294, 'PSCD')
# (295, 'PSCE')
# (296, 'PSCF')
# (297, 'PSCH')
# (298, 'PSCI')
# (299, 'PSCM')
# (300, 'PSCT')
# (301, 'PSCU')
# (302, 'PSET')
# (303, 'PSL')
# (304, 'PTF')
# (305, 'PTH')
# (306, 'PUI')
# (307, 'PXI')
# (308, 'PY')
# (309, 'PYZ')
# (310, 'QABA')
# (311, 'QAT')
# (312, 'QCLN')
# (313, 'QQC')
# (314, 'QQD')
# (315, 'QQEW')
# (316, 'QQQJ')
# (317, 'QQQM')
# (318, 'QQQN')
# (319, 'QQXT')
# (320, 'QTEC')
# (321, 'QYLD')
# (322, 'QYLG')
# (323, 'RDVY')
# (324, 'RFAP')
# (325, 'RFDI')
# (326, 'RFEM')
# (327, 'RFEU')
# (328, 'RING')
# (329, 'RNDM')
# (330, 'RNDV')
# (331, 'RNEM')
# (332, 'RNLC')
# (333, 'RNMC')
# (334, 'RNRG')
# (335, 'RNSC')
# (336, 'ROBT')
# (337, 'RTH')
# (338, 'SCZ')
# (339, 'SDG')
# (340, 'SDVY')
# (341, 'SHLD')
# (342, 'SHV')
# (343, 'SHY')
# (344, 'SKOR')
# (345, 'SKYU')
# (346, 'SKYY')
# (347, 'SLQD')
# (348, 'SMCP')
# (349, 'SMH')
# (350, 'SNLN')
# (351, 'SNSR')
# (352, 'SNUG')
# (353, 'SOCL')
# (354, 'SOXX')
# (355, 'SPQQ')
# (356, 'SQLV')
# (357, 'SQQQ')
# (358, 'SRET')
# (359, 'SUSB')
# (360, 'SUSC')
# (361, 'SUSL')
# (362, 'TDIV')
# (363, 'TLT')
# (364, 'TQQQ')
# (365, 'TUR')
# (366, 'TUSA')
# (367, 'UAE')
# (368, 'UCYB')
# (369, 'UFO')
# (370, 'USIG')
# (371, 'USLB')
# (372, 'USMC')
# (373, 'USXF')
# (374, 'VCIT')
# (375, 'VCLT')
# (376, 'VCSH')
# (377, 'VETS')
# (378, 'VGIT')
# (379, 'VGLT')
# (380, 'VGSH')
# (381, 'VIGI')
# (382, 'VMBS')
# (383, 'VNQI')
# (384, 'VONE')
# (385, 'VONG')
# (386, 'VONV')
# (387, 'VPN')
# (388, 'VRIG')
# (389, 'VSDA')
# (390, 'VSMV')
# (391, 'VTC')
# (392, 'VTHR')
# (393, 'VTIP')
# (394, 'VTRN')
# (395, 'VTWG')
# (396, 'VTWO')
# (397, 'VTWV')
# (398, 'VWOB')
# (399, 'VXUS')
# (400, 'VYMI')
# (401, 'WBND')
# (402, 'WCBR')
# (403, 'WCLD')
# (404, 'WINC')
# (405, 'WOOD')
# (406, 'XT')
# (407, 'YLDE')
# (408, 'AAA')
# (409, 'AAAU')
# (410, 'AADR')
# (411, 'ABEQ')
# (412, 'ACES')
# (413, 'ACIO')
# (414, 'ACSG')
# (415, 'ACSI')
# (416, 'ACTV')
# (417, 'ACVF')
# (418, 'ACWF')
# (419, 'ACWV')
# (420, 'ADFI')
# (421, 'ADME')
# (422, 'AESR')
# (423, 'AFIF')
# (424, 'AFK')
# (425, 'AFLG')
# (426, 'AFMC')
# (427, 'AFSM')
# (428, 'AFTY')
# (429, 'AGG')
# (430, 'AGGY')
# (431, 'AGQ')
# (432, 'AGT')
# (433, 'AGZ')
# (434, 'AIEQ')
# (435, 'AIIQ')
# (436, 'ALFA')
# (437, 'ALTL')
# (438, 'ALTS')
# (439, 'AMER')
# (440, 'AMLP')
# (441, 'AMNA')
# (442, 'AMND')
# (443, 'AMOM')
# (444, 'AMZA')
# (445, 'ANEW')
# (446, 'AOA')
# (447, 'AOK')
# (448, 'AOM')
# (449, 'AOR')
# (450, 'ARB')
# (451, 'ARCM')
# (452, 'ARGT')
# (453, 'ARKF')
# (454, 'ARKG')
# (455, 'ARKK')
# (456, 'ARKQ')
# (457, 'ARKW')
# (458, 'ARMR')
# (459, 'ASEA')
# (460, 'ASHR')
# (461, 'ASHS')
# (462, 'ASHX')
# (463, 'AUGZ')
# (464, 'AUSF')
# (465, 'AVDE')
# (466, 'AVDG')
# (467, 'AVDR')
# (468, 'AVDV')
# (469, 'AVEM')
# (470, 'AVIG')
# (471, 'AVMU')
# (472, 'AVSF')
# (473, 'AVUS')
# (474, 'AVUV')
# (475, 'AWAY')
# (476, 'AWTM')
# (477, 'AZAA')
# (478, 'AZAJ')
# (479, 'AZAL')
# (480, 'AZAO')
# (481, 'AZBA')
# (482, 'AZBJ')
# (483, 'AZBL')
# (484, 'AZBO')
# (485, 'BAB')
# (486, 'BAPR')
# (487, 'BATT')
# (488, 'BAUG')
# (489, 'BBAX')
# (490, 'BBC')
# (491, 'BBCA')
# (492, 'BBEU')
# (493, 'BBIN')
# (494, 'BBJP')
# (495, 'BBMC')
# (496, 'BBP')
# (497, 'BBRE')
# (498, 'BBSA')
# (499, 'BBSC')
# (500, 'BBUS')
# (501, 'BCD')
# (502, 'BCI')
# (503, 'BDCX')
# (504, 'BDEC')
# (505, 'BDRY')
# (506, 'BETZ')
# (507, 'BFEB')
# (508, 'BFOR')
# (509, 'BFTR')
# (510, 'BGLD')
# (511, 'BIBL')
# (512, 'BIL')
# (513, 'BILS')
# (514, 'BIV')
# (515, 'BIZD')
# (516, 'BJAN')
# (517, 'BJUL')
# (518, 'BJUN')
# (519, 'BKAG')
# (520, 'BKEM')
# (521, 'BKF')
# (522, 'BKHY')
# (523, 'BKIE')
# (524, 'BKLC')
# (525, 'BKLN')
# (526, 'BKMC')
# (527, 'BKSB')
# (528, 'BKSE')
# (529, 'BLDG')
# (530, 'BLES')
# (531, 'BLHY')
# (532, 'BLOK')
# (533, 'BLV')
# (534, 'BMAR')
# (535, 'BMAY')
# (536, 'BMED')
# (537, 'BNDC')
# (538, 'BNE')
# (539, 'BNOV')
# (540, 'BOB')
# (541, 'BOCT')
# (542, 'BOIL')
# (543, 'BOND')
# (544, 'BOSS')
# (545, 'BOUT')
# (546, 'BRF')
# (547, 'BRZU')
# (548, 'BSEP')
# (549, 'BSV')
# (550, 'BTAL')
# (551, 'BTEK')
# (552, 'BUFD')
# (553, 'BUFF')
# (554, 'BUFR')
# (555, 'BUL')
# (556, 'BUYZ')
# (557, 'BWX')
# (558, 'BWZ')
# (559, 'BYLD')
# (560, 'BZQ')
# (561, 'CALF')
# (562, 'CANE')
# (563, 'CBLS')
# (564, 'CBON')
# (565, 'CBSE')
# (566, 'CBTG')
# (567, 'CCON')
# (568, 'CCOR')
# (569, 'CCRV')
# (570, 'CEF')
# (571, 'CEFD')
# (572, 'CEFS')
# (573, 'CEMB')
# (574, 'CEW')
# (575, 'CFCV')
# (576, 'CGW')
# (577, 'CHAD')
# (578, 'CHAU')
# (579, 'CHGX')
# (580, 'CHIC')
# (581, 'CHIE')
# (582, 'CHIH')
# (583, 'CHII')
# (584, 'CHIK')
# (585, 'CHIL')
# (586, 'CHIM')
# (587, 'CHIQ')
# (588, 'CHIR')
# (589, 'CHIS')
# (590, 'CHIU')
# (591, 'CHIX')
# (592, 'CLDL')
# (593, 'CLDS')
# (594, 'CLIX')
# (595, 'CLTL')
# (596, 'CMBS')
# (597, 'CMDY')
# (598, 'CMF')
# (599, 'CN')
# (600, 'CNBS')
# (601, 'CNRG')
# (602, 'CNXT')
# (603, 'CNYA')
# (604, 'COM')
# (605, 'COMB')
# (606, 'COPX')
# (607, 'CORN')
# (608, 'CORP')
# (609, 'COWZ')
# (610, 'CPER')
# (611, 'CPI')
# (612, 'CQQQ')
# (613, 'CRAK')
# (614, 'CRBN')
# (615, 'CSD')
# (616, 'CSM')
# (617, 'CURE')
# (618, 'CUT')
# (619, 'CVY')
# (620, 'CWB')
# (621, 'CWEB')
# (622, 'CWI')
# (623, 'CWS')
# (624, 'CYB')
# (625, 'CZA')
# (626, 'DALT')
# (627, 'DAUG')
# (628, 'DBA')
# (629, 'DBAW')
# (630, 'DBB')
# (631, 'DBC')
# (632, 'DBE')
# (633, 'DBEF')
# (634, 'DBEH')
# (635, 'DBEM')
# (636, 'DBEU')
# (637, 'DBEZ')
# (638, 'DBGR')
# (639, 'DBJA')
# (640, 'DBJP')
# (641, 'DBLV')
# (642, 'DBMF')
# (643, 'DBO')
# (644, 'DBOC')
# (645, 'DBP')
# (646, 'DBS')
# (647, 'DBV')
# (648, 'DDEC')
# (649, 'DDG')
# (650, 'DDLS')
# (651, 'DDM')
# (652, 'DDWM')
# (653, 'DECZ')
# (654, 'DEED')
# (655, 'DEEF')
# (656, 'DEEP')
# (657, 'DEF')
# (658, 'DEFA')
# (659, 'DEFN')
# (660, 'DEM')
# (661, 'DES')
# (662, 'DEUS')
# (663, 'DEW')
# (664, 'DFAE')
# (665, 'DFAI')
# (666, 'DFAU')
# (667, 'DFE')
# (668, 'DFEB')
# (669, 'DFEN')
# (670, 'DFHY')
# (671, 'DFJ')
# (672, 'DFND')
# (673, 'DFNV')
# (674, 'DGL')
# (675, 'DGRO')
# (676, 'DGS')
# (677, 'DGT')
# (678, 'DHS')
# (679, 'DIA')
# (680, 'DIAL')
# (681, 'DIG')
# (682, 'DIM')
# (683, 'DIV')
# (684, 'DIVA')
# (685, 'DIVB')
# (686, 'DIVO')
# (687, 'DIVZ')
# (688, 'DJAN')
# (689, 'DJD')
# (690, 'DJUL')
# (691, 'DJUN')
# (692, 'DLN')
# (693, 'DLS')
# (694, 'DMAY')
# (695, 'DMDV')
# (696, 'DMRE')
# (697, 'DMRI')
# (698, 'DMRL')
# (699, 'DMRM')
# (700, 'DMRS')
# (701, 'DNL')
# (702, 'DNOV')
# (703, 'DOCT')
# (704, 'DOG')
# (705, 'DOL')
# (706, 'DON')
# (707, 'DOO')
# (708, 'DPST')
# (709, 'DRIP')
# (710, 'DRN')
# (711, 'DRSK')
# (712, 'DRV')
# (713, 'DRW')
# (714, 'DSEP')
# (715, 'DSI')
# (716, 'DSJA')
# (717, 'DSOC')
# (718, 'DSTL')
# (719, 'DSTX')
# (720, 'DTD')
# (721, 'DTEC')
# (722, 'DTH')
# (723, 'DTN')
# (724, 'DUDE')
# (725, 'DUG')
# (726, 'DURA')
# (727, 'DUSL')
# (728, 'DUST')
# (729, 'DVYA')
# (730, 'DVYE')
# (731, 'DWM')
# (732, 'DWMF')
# (733, 'DWX')
# (734, 'DXD')
# (735, 'DXJ')
# (736, 'DYHG')
# (737, 'DYNF')
# (738, 'EAGG')
# (739, 'EAOA')
# (740, 'EAOK')
# (741, 'EAOM')
# (742, 'EAOR')
# (743, 'EASG')
# (744, 'EBLU')
# (745, 'EBND')
# (746, 'ECH')
# (747, 'ECLN')
# (748, 'ECNS')
# (749, 'ECON')
# (750, 'ECOZ')
# (751, 'EDC')
# (752, 'EDEN')
# (753, 'EDIV')
# (754, 'EDOG')
# (755, 'EDOW')
# (756, 'EDV')
# (757, 'EDZ')
# (758, 'EELV')
# (759, 'EEM')
# (760, 'EEMD')
# (761, 'EEMO')
# (762, 'EEMS')
# (763, 'EEMV')
# (764, 'EEMX')
# (765, 'EES')
# (766, 'EET')
# (767, 'EEV')
# (768, 'EFA')
# (769, 'EFAD')
# (770, 'EFAV')
# (771, 'EFAX')
# (772, 'EFG')
# (773, 'EFIV')
# (774, 'EFNL')
# (775, 'EFO')
# (776, 'EFU')
# (777, 'EFV')
# (778, 'EFZ')
# (779, 'EGIS')
# (780, 'EGPT')
# (781, 'EIDO')
# (782, 'EINC')
# (783, 'EIRL')
# (784, 'EIS')
# (785, 'EJAN')
# (786, 'EJUL')
# (787, 'EKAR')
# (788, 'ELD')
# (789, 'EMAG')
# (790, 'EMBD')
# (791, 'EMBH')
# (792, 'EMDV')
# (793, 'EMFM')
# (794, 'EMGF')
# (795, 'EMHY')
# (796, 'EMLC')
# (797, 'EMLP')
# (798, 'EMMF')
# (799, 'EMNT')
# (800, 'EMQQ')
# (801, 'EMSG')
# (802, 'EMSH')
# (803, 'EMTL')
# (804, 'EMTY')
# (805, 'ENFR')
# (806, 'ENOR')
# (807, 'ENTR')
# (808, 'EPHE')
# (809, 'EPI')
# (810, 'EPOL')
# (811, 'EPP')
# (812, 'EPRF')
# (813, 'EPS')
# (814, 'EPU')
# (815, 'EPV')
# (816, 'EQAL')
# (817, 'EQL')
# (818, 'EQOP')
# (819, 'EQWL')
# (820, 'ERM')
# (821, 'ERSX')
# (822, 'ERUS')
# (823, 'ERX')
# (824, 'ERY')
# (825, 'ESCR')
# (826, 'ESEB')
# (827, 'ESG')
# (828, 'ESGA')
# (829, 'ESGG')
# (830, 'ESGN')
# (831, 'ESGS')
# (832, 'ESGV')
# (833, 'ESHY')
# (834, 'ESML')
# (835, 'ESNG')
# (836, 'ETHO')
# (837, 'EUCG')
# (838, 'EUDG')
# (839, 'EUDV')
# (840, 'EUM')
# (841, 'EUO')
# (842, 'EURL')
# (843, 'EURZ')
# (844, 'EUSA')
# (845, 'EUSB')
# (846, 'EUSC')
# (847, 'EVX')
# (848, 'EWA')
# (849, 'EWC')
# (850, 'EWCO')
# (851, 'EWD')
# (852, 'EWG')
# (853, 'EWGS')
# (854, 'EWH')
# (855, 'EWI')
# (856, 'EWJ')
# (857, 'EWK')
# (858, 'EWL')
# (859, 'EWM')
# (860, 'EWMC')
# (861, 'EWN')
# (862, 'EWO')
# (863, 'EWP')
# (864, 'EWQ')
# (865, 'EWRE')
# (866, 'EWS')
# (867, 'EWSC')
# (868, 'EWT')
# (869, 'EWU')
# (870, 'EWUS')
# (871, 'EWV')
# (872, 'EWW')
# (873, 'EWX')
# (874, 'EWY')
# (875, 'EWZ')
# (876, 'EXI')
# (877, 'EYLD')
# (878, 'EZA')
# (879, 'EZJ')
# (880, 'EZM')
# (881, 'EZU')
# (882, 'FAN')
# (883, 'FAS')
# (884, 'FAUG')
# (885, 'FAZ')
# (886, 'FBCG')
# (887, 'FBCV')
# (888, 'FBND')
# (889, 'FBT')
# (890, 'FCG')
# (891, 'FCOM')
# (892, 'FCOR')
# (893, 'FCPI')
# (894, 'FCTR')
# (895, 'FDD')
# (896, 'FDEC')
# (897, 'FDEM')
# (898, 'FDEV')
# (899, 'FDG')
# (900, 'FDHY')
# (901, 'FDIS')
# (902, 'FDL')
# (903, 'FDLO')
# (904, 'FDM')
# (905, 'FDMO')
# (906, 'FDN')
# (907, 'FDRR')
# (908, 'FDVV')
# (909, 'FEBZ')
# (910, 'FEDX')
# (911, 'FENY')
# (912, 'FEVR')
# (913, 'FEZ')
# (914, 'FFEB')
# (915, 'FFHG')
# (916, 'FFIU')
# (917, 'FFR')
# (918, 'FFSG')
# (919, 'FFTG')
# (920, 'FFTI')
# (921, 'FFTY')
# (922, 'FGD')
# (923, 'FGRO')
# (924, 'FHLC')
# (925, 'FIBR')
# (926, 'FIDI')
# (927, 'FIDU')
# (928, 'FILL')
# (929, 'FISR')
# (930, 'FITE')
# (931, 'FIVA')
# (932, 'FIVG')
# (933, 'FIW')
# (934, 'FJAN')
# (935, 'FJNK')
# (936, 'FJUL')
# (937, 'FJUN')
# (938, 'FLAU')
# (939, 'FLAX')
# (940, 'FLBL')
# (941, 'FLBR')
# (942, 'FLCA')
# (943, 'FLCB')
# (944, 'FLCH')
# (945, 'FLCO')
# (946, 'FLDR')
# (947, 'FLEE')
# (948, 'FLEH')
# (949, 'FLFR')
# (950, 'FLGB')
# (951, 'FLGR')
# (952, 'FLGV')
# (953, 'FLHK')
# (954, 'FLHY')
# (955, 'FLIA')
# (956, 'FLIN')
# (957, 'FLIY')
# (958, 'FLJH')
# (959, 'FLJP')
# (960, 'FLKR')
# (961, 'FLLA')
# (962, 'FLLV')
# (963, 'FLM')
# (964, 'FLMB')
# (965, 'FLMI')
# (966, 'FLMX')
# (967, 'FLOT')
# (968, 'FLQD')
# (969, 'FLQE')
# (970, 'FLQG')
# (971, 'FLQH')
# (972, 'FLQL')
# (973, 'FLQM')
# (974, 'FLQS')
# (975, 'FLRG')
# (976, 'FLRN')
# (977, 'FLRT')
# (978, 'FLRU')
# (979, 'FLSA')
# (980, 'FLSP')
# (981, 'FLSW')
# (982, 'FLTB')
# (983, 'FLTR')
# (984, 'FLTW')
# (985, 'FLUD')
# (986, 'FLV')
# (987, 'FLYT')
# (988, 'FLZA')
# (989, 'FM')
# (990, 'FMAG')
# (991, 'FMAT')
# (992, 'FMAY')
# (993, 'FMF')
# (994, 'FMIL')
# (995, 'FNCL')
# (996, 'FNDA')
# (997, 'FNDB')
# (998, 'FNDC')
# (999, 'FNDE')
# (1000, 'FNDF')
# (1001, 'FNDX')
# (1002, 'FNI')
# (1003, 'FNOV')
# (1004, 'FOCT')
# (1005, 'FOVL')
# (1006, 'FPE')
# (1007, 'FPEI')
# (1008, 'FPRO')
# (1009, 'FPX')
# (1010, 'FQAL')
# (1011, 'FRAK')
# (1012, 'FRDM')
# (1013, 'FREL')
# (1014, 'FRI')
# (1015, 'FSEP')
# (1016, 'FSMB')
# (1017, 'FSMD')
# (1018, 'FSMO')
# (1019, 'FSTA')
# (1020, 'FTEC')
# (1021, 'FTLS')
# (1022, 'FTSD')
# (1023, 'FUMB')
# (1024, 'FUNL')
# (1025, 'FUT')
# (1026, 'FUTY')
# (1027, 'FVAL')
# (1028, 'FVD')
# (1029, 'FWDB')
# (1030, 'FXA')
# (1031, 'FXB')
# (1032, 'FXC')
# (1033, 'FXD')
# (1034, 'FXE')
# (1035, 'FXF')
# (1036, 'FXG')
# (1037, 'FXH')
# (1038, 'FXI')
# (1039, 'FXL')
# (1040, 'FXN')
# (1041, 'FXO')
# (1042, 'FXP')
# (1043, 'FXR')
# (1044, 'FXU')
# (1045, 'FXY')
# (1046, 'FXZ')
# (1047, 'FYLD')
# (1048, 'GAA')
# (1049, 'GAL')
# (1050, 'GAMR')
# (1051, 'GBDV')
# (1052, 'GBF')
# (1053, 'GBGR')
# (1054, 'GBIL')
# (1055, 'GBLO')
# (1056, 'GBUG')
# (1057, 'GCC')
# (1058, 'GCOR')
# (1059, 'GCOW')
# (1060, 'GDMA')
# (1061, 'GDX')
# (1062, 'GDXD')
# (1063, 'GDXJ')
# (1064, 'GDXU')
# (1065, 'GEM')
# (1066, 'GERM')
# (1067, 'GHYB')
# (1068, 'GHYG')
# (1069, 'GIGB')
# (1070, 'GII')
# (1071, 'GINN')
# (1072, 'GLCN')
# (1073, 'GLD')
# (1074, 'GLDM')
# (1075, 'GLIF')
# (1076, 'GLIN')
# (1077, 'GLL')
# (1078, 'GLRY')
# (1079, 'GLTR')
# (1080, 'GMF')
# (1081, 'GMOM')
# (1082, 'GNR')
# (1083, 'GOAT')
# (1084, 'GOAU')
# (1085, 'GOEX')
# (1086, 'GOVT')
# (1087, 'GOVZ')
# (1088, 'GQRE')
# (1089, 'GREK')
# (1090, 'GRES')
# (1091, 'GRNB')
# (1092, 'GSEE')
# (1093, 'GSEU')
# (1094, 'GSEW')
# (1095, 'GSG')
# (1096, 'GSID')
# (1097, 'GSIE')
# (1098, 'GSIG')
# (1099, 'GSJY')
# (1100, 'GSLC')
# (1101, 'GSPY')
# (1102, 'GSSC')
# (1103, 'GSST')
# (1104, 'GSUS')
# (1105, 'GSY')
# (1106, 'GTIP')
# (1107, 'GTO')
# (1108, 'GUNR')
# (1109, 'GURU')
# (1110, 'GUSH')
# (1111, 'GVAL')
# (1112, 'GVI')
# (1113, 'GVIP')
# (1114, 'GWX')
# (1115, 'GXC')
# (1116, 'GXF')
# (1117, 'GXG')
# (1118, 'GYLD')
# (1119, 'HACK')
# (1120, 'HAIL')
# (1121, 'HAP')
# (1122, 'HART')
# (1123, 'HAUZ')
# (1124, 'HAWX')
# (1125, 'HCRB')
# (1126, 'HDAW')
# (1127, 'HDEF')
# (1128, 'HDG')
# (1129, 'HDGE')
# (1130, 'HDIV')
# (1131, 'HDMV')
# (1132, 'HDV')
# (1133, 'HEDJ')
# (1134, 'HEEM')
# (1135, 'HEFA')
# (1136, 'HEGD')
# (1137, 'HELX')
# (1138, 'HEWC')
# (1139, 'HEWJ')
# (1140, 'HEWU')
# (1141, 'HEWW')
# (1142, 'HEZU')
# (1143, 'HFXI')
# (1144, 'HIBL')
# (1145, 'HIBS')
# (1146, 'HIPR')
# (1147, 'HIPS')
# (1148, 'HJPX')
# (1149, 'HMOP')
# (1150, 'HOLD')
# (1151, 'HOMZ')
# (1152, 'HSCZ')
# (1153, 'HSMV')
# (1154, 'HSRT')
# (1155, 'HTAB')
# (1156, 'HTEC')
# (1157, 'HTRB')
# (1158, 'HTUS')
# (1159, 'HUSV')
# (1160, 'HYBB')
# (1161, 'HYD')
# (1162, 'HYDB')
# (1163, 'HYDW')
# (1164, 'HYEM')
# (1165, 'HYG')
# (1166, 'HYGH')
# (1167, 'HYGV')
# (1168, 'HYHG')
# (1169, 'HYLB')
# (1170, 'HYLD')
# (1171, 'HYLV')
# (1172, 'HYMB')
# (1173, 'HYS')
# (1174, 'HYTR')
# (1175, 'HYUP')
# (1176, 'HYXU')
# (1177, 'IAGG')
# (1178, 'IAI')
# (1179, 'IAK')
# (1180, 'IAT')
# (1181, 'IAU')
# (1182, 'IAUF')
# (1183, 'IBCE')
# (1184, 'IBD')
# (1185, 'IBDD')
# (1186, 'IBDM')
# (1187, 'IBDN')
# (1188, 'IBDO')
# (1189, 'IBDP')
# (1190, 'IBDQ')
# (1191, 'IBDR')
# (1192, 'IBDS')
# (1193, 'IBDT')
# (1194, 'IBDU')
# (1195, 'IBDV')
# (1196, 'IBHA')
# (1197, 'IBHB')
# (1198, 'IBHC')
# (1199, 'IBHD')
# (1200, 'IBHE')
# (1201, 'IBHF')
# (1202, 'IBMJ')
# (1203, 'IBMK')
# (1204, 'IBML')
# (1205, 'IBMM')
# (1206, 'IBMN')
# (1207, 'IBMO')
# (1208, 'IBMP')
# (1209, 'IBMQ')
# (1210, 'IBND')
# (1211, 'IBUY')
# (1212, 'ICF')
# (1213, 'ICOL')
# (1214, 'ICOW')
# (1215, 'ICSH')
# (1216, 'ICVT')
# (1217, 'IDEV')
# (1218, 'IDHD')
# (1219, 'IDHQ')
# (1220, 'IDIV')
# (1221, 'IDLV')
# (1222, 'IDMO')
# (1223, 'IDNA')
# (1224, 'IDOG')
# (1225, 'IDRV')
# (1226, 'IDU')
# (1227, 'IDV')
# (1228, 'IDX')
# (1229, 'IECS')
# (1230, 'IEDI')
# (1231, 'IEFA')
# (1232, 'IEFN')
# (1233, 'IEHS')
# (1234, 'IEIH')
# (1235, 'IEME')
# (1236, 'IEMG')
# (1237, 'IEO')
# (1238, 'IETC')
# (1239, 'IEUR')
# (1240, 'IEV')
# (1241, 'IEZ')
# (1242, 'IFRA')
# (1243, 'IG')
# (1244, 'IGBH')
# (1245, 'IGE')
# (1246, 'IGEB')
# (1247, 'IGHG')
# (1248, 'IGLB')
# (1249, 'IGM')
# (1250, 'IGN')
# (1251, 'IGRO')
# (1252, 'IGV')
# (1253, 'IHAK')
# (1254, 'IHDG')
# (1255, 'IHE')
# (1256, 'IHF')
# (1257, 'IHI')
# (1258, 'IHY')
# (1259, 'IIGD')
# (1260, 'IIGV')
# (1261, 'IJAN')
# (1262, 'IJH')
# (1263, 'IJJ')
# (1264, 'IJK')
# (1265, 'IJR')
# (1266, 'IJS')
# (1267, 'IJUL')
# (1268, 'ILF')
# (1269, 'ILTB')
# (1270, 'IMOM')
# (1271, 'IMTB')
# (1272, 'IMTM')
# (1273, 'INCO')
# (1274, 'INDA')
# (1275, 'INDF')
# (1276, 'INDL')
# (1277, 'INDS')
# (1278, 'INFL')
# (1279, 'INKM')
# (1280, 'INTF')
# (1281, 'IOO')
# (1282, 'IPAC')
# (1283, 'IPAY')
# (1284, 'IPFF')
# (1285, 'IPO')
# (1286, 'IPOS')
# (1287, 'IQDE')
# (1288, 'IQDF')
# (1289, 'IQDG')
# (1290, 'IQDY')
# (1291, 'IQIN')
# (1292, 'IQLT')
# (1293, 'IQM')
# (1294, 'IQSI')
# (1295, 'IQSU')
# (1296, 'IRBO')
# (1297, 'ISCF')
# (1298, 'ISMD')
# (1299, 'ISRA')
# (1300, 'ISWN')
# (1301, 'ISZE')
# (1302, 'ITA')
# (1303, 'ITB')
# (1304, 'ITEQ')
# (1305, 'ITM')
# (1306, 'ITOT')
# (1307, 'IVAL')
# (1308, 'IVDG')
# (1309, 'IVE')
# (1310, 'IVES')
# (1311, 'IVLC')
# (1312, 'IVLU')
# (1313, 'IVOG')
# (1314, 'IVOL')
# (1315, 'IVOO')
# (1316, 'IVOV')
# (1317, 'IVRA')
# (1318, 'IVSG')
# (1319, 'IVV')
# (1320, 'IVW')
# (1321, 'IWB')
# (1322, 'IWC')
# (1323, 'IWD')
# (1324, 'IWDL')
# (1325, 'IWF')
# (1326, 'IWFH')
# (1327, 'IWFL')
# (1328, 'IWL')
# (1329, 'IWM')
# (1330, 'IWML')
# (1331, 'IWN')
# (1332, 'IWO')
# (1333, 'IWP')
# (1334, 'IWR')
# (1335, 'IWS')
# (1336, 'IWV')
# (1337, 'IWX')
# (1338, 'IWY')
# (1339, 'IXC')
# (1340, 'IXG')
# (1341, 'IXJ')
# (1342, 'IXN')
# (1343, 'IXP')
# (1344, 'IXSE')
# (1345, 'IYC')
# (1346, 'IYE')
# (1347, 'IYF')
# (1348, 'IYG')
# (1349, 'IYH')
# (1350, 'IYJ')
# (1351, 'IYK')
# (1352, 'IYLD')
# (1353, 'IYM')
# (1354, 'IYR')
# (1355, 'IYT')
# (1356, 'IYW')
# (1357, 'IYY')
# (1358, 'IYZ')
# (1359, 'IZRL')
# (1360, 'JAAA')
# (1361, 'JAGG')
# (1362, 'JANZ')
# (1363, 'JCPB')
# (1364, 'JCTR')
# (1365, 'JDIV')
# (1366, 'JDST')
# (1367, 'JEPI')
# (1368, 'JETS')
# (1369, 'JGLD')
# (1370, 'JHCS')
# (1371, 'JHEM')
# (1372, 'JHMA')
# (1373, 'JHMC')
# (1374, 'JHMD')
# (1375, 'JHME')
# (1376, 'JHMF')
# (1377, 'JHMH')
# (1378, 'JHMI')
# (1379, 'JHML')
# (1380, 'JHMM')
# (1381, 'JHMS')
# (1382, 'JHMT')
# (1383, 'JHMU')
# (1384, 'JHSC')
# (1385, 'JIG')
# (1386, 'JIGB')
# (1387, 'JKD')
# (1388, 'JKE')
# (1389, 'JKF')
# (1390, 'JKG')
# (1391, 'JKH')
# (1392, 'JKJ')
# (1393, 'JKK')
# (1394, 'JKL')
# (1395, 'JMBS')
# (1396, 'JMIN')
# (1397, 'JMOM')
# (1398, 'JMST')
# (1399, 'JMUB')
# (1400, 'JNK')
# (1401, 'JNUG')
# (1402, 'JOYY')
# (1403, 'JPEM')
# (1404, 'JPHY')
# (1405, 'JPIB')
# (1406, 'JPIN')
# (1407, 'JPMB')
# (1408, 'JPME')
# (1409, 'JPN')
# (1410, 'JPSE')
# (1411, 'JPST')
# (1412, 'JPUS')
# (1413, 'JPXN')
# (1414, 'JQUA')
# (1415, 'JSTC')
# (1416, 'JULZ')
# (1417, 'JUST')
# (1418, 'JVAL')
# (1419, 'JXI')
# (1420, 'KALL')
# (1421, 'KAPR')
# (1422, 'KARS')
# (1423, 'KBA')
# (1424, 'KBE')
# (1425, 'KBUY')
# (1426, 'KCCB')
# (1427, 'KCE')
# (1428, 'KCNY')
# (1429, 'KDFI')
# (1430, 'KEMQ')
# (1431, 'KEMX')
# (1432, 'KESG')
# (1433, 'KFVG')
# (1434, 'KFYP')
# (1435, 'KGRN')
# (1436, 'KIE')
# (1437, 'KJAN')
# (1438, 'KJUL')
# (1439, 'KLCD')
# (1440, 'KLDW')
# (1441, 'KMED')
# (1442, 'KMLM')
# (1443, 'KNG')
# (1444, 'KNGS')
# (1445, 'KOCT')
# (1446, 'KOIN')
# (1447, 'KOKU')
# (1448, 'KOLD')
# (1449, 'KOMP')
# (1450, 'KORP')
# (1451, 'KORU')
# (1452, 'KRBN')
# (1453, 'KRE')
# (1454, 'KSA')
# (1455, 'KSCD')
# (1456, 'KSTR')
# (1457, 'KURE')
# (1458, 'KVLE')
# (1459, 'KWEB')
# (1460, 'KWT')
# (1461, 'KXI')
# (1462, 'LABD')
# (1463, 'LABU')
# (1464, 'LBAY')
# (1465, 'LBJ')
# (1466, 'LCG')
# (1467, 'LCR')
# (1468, 'LDRS')
# (1469, 'LDUR')
# (1470, 'LEAD')
# (1471, 'LEMB')
# (1472, 'LEND')
# (1473, 'LFEQ')
# (1474, 'LGH')
# (1475, 'LGLV')
# (1476, 'LGOV')
# (1477, 'LIT')
# (1478, 'LIV')
# (1479, 'LKOR')
# (1480, 'LOPP')
# (1481, 'LOUP')
# (1482, 'LOWC')
# (1483, 'LQD')
# (1484, 'LQDH')
# (1485, 'LQDI')
# (1486, 'LRGF')
# (1487, 'LSAF')
# (1488, 'LSAT')
# (1489, 'LSLT')
# (1490, 'LSST')
# (1491, 'LTL')
# (1492, 'LTPZ')
# (1493, 'LUXE')
# (1494, 'LVHI')
# (1495, 'LVOL')
# (1496, 'LYFE')
# (1497, 'MAAX')
# (1498, 'MAGA')
# (1499, 'MARB')
# (1500, 'MBBB')
# (1501, 'MBND')
# (1502, 'MBSD')
# (1503, 'MCRO')
# (1504, 'MDY')
# (1505, 'MDYG')
# (1506, 'MDYV')
# (1507, 'MEAR')
# (1508, 'MEXX')
# (1509, 'MFDX')
# (1510, 'MFEM')
# (1511, 'MFMS')
# (1512, 'MFUS')
# (1513, 'MGC')
# (1514, 'MGK')
# (1515, 'MGMT')
# (1516, 'MGV')
# (1517, 'MID')
# (1518, 'MIDF')
# (1519, 'MIDU')
# (1520, 'MIG')
# (1521, 'MINC')
# (1522, 'MINT')
# (1523, 'MJ')
# (1524, 'MJJ')
# (1525, 'MJO')
# (1526, 'MLN')
# (1527, 'MLPA')
# (1528, 'MLPR')
# (1529, 'MLPX')
# (1530, 'MMIN')
# (1531, 'MMIT')
# (1532, 'MMLG')
# (1533, 'MMTM')
# (1534, 'MNA')
# (1535, 'MOAT')
# (1536, 'MOM')
# (1537, 'MOO')
# (1538, 'MOON')
# (1539, 'MORT')
# (1540, 'MOTI')
# (1541, 'MOTO')
# (1542, 'MRAD')
# (1543, 'MRGR')
# (1544, 'MRSK')
# (1545, 'MSOS')
# (1546, 'MSTB')
# (1547, 'MSVX')
# (1548, 'MTGP')
# (1549, 'MTUL')
# (1550, 'MTUM')
# (1551, 'MUB')
# (1552, 'MUNI')
# (1553, 'MUST')
# (1554, 'MVRL')
# (1555, 'MVV')
# (1556, 'MXDU')
# (1557, 'MXI')
# (1558, 'MYY')
# (1559, 'MZZ')
# (1560, 'NACP')
# (1561, 'NAIL')
# (1562, 'NANR')
# (1563, 'NAPR')
# (1564, 'NEAR')
# (1565, 'NERD')
# (1566, 'NETL')
# (1567, 'NFLT')
# (1568, 'NFRA')
# (1569, 'NGE')
# (1570, 'NIFE')
# (1571, 'NJAN')
# (1572, 'NJUL')
# (1573, 'NLR')
# (1574, 'NOBL')
# (1575, 'NOCT')
# (1576, 'NORW')
# (1577, 'NTSX')
# (1578, 'NUAG')
# (1579, 'NUBD')
# (1580, 'NUDM')
# (1581, 'NUEM')
# (1582, 'NUGT')
# (1583, 'NUHY')
# (1584, 'NULC')
# (1585, 'NULG')
# (1586, 'NULV')
# (1587, 'NUMG')
# (1588, 'NUMV')
# (1589, 'NURE')
# (1590, 'NUSA')
# (1591, 'NUSC')
# (1592, 'NUSI')
# (1593, 'NVMZ')
# (1594, 'NVQ')
# (1595, 'NYF')
# (1596, 'OBOR')
# (1597, 'OCIO')
# (1598, 'OCTZ')
# (1599, 'OEF')
# (1600, 'OEUR')
# (1601, 'OGIG')
# (1602, 'OIH')
# (1603, 'OILK')
# (1604, 'OMFL')
# (1605, 'OMFS')
# (1606, 'ONEO')
# (1607, 'ONEV')
# (1608, 'ONEY')
# (1609, 'ONLN')
# (1610, 'ONOF')
# (1611, 'OPER')
# (1612, 'OSCV')
# (1613, 'OUNZ')
# (1614, 'OUSA')
# (1615, 'OUSM')
# (1616, 'OVB')
# (1617, 'OVF')
# (1618, 'OVL')
# (1619, 'OVLH')
# (1620, 'OVM')
# (1621, 'OVS')
# (1622, 'OVT')
# (1623, 'PAK')
# (1624, 'PALC')
# (1625, 'PALL')
# (1626, 'PAMC')
# (1627, 'PAPR')
# (1628, 'PAUG')
# (1629, 'PAVE')
# (1630, 'PAWZ')
# (1631, 'PBD')
# (1632, 'PBDM')
# (1633, 'PBE')
# (1634, 'PBEE')
# (1635, 'PBJ')
# (1636, 'PBND')
# (1637, 'PBP')
# (1638, 'PBS')
# (1639, 'PBSM')
# (1640, 'PBTP')
# (1641, 'PBUS')
# (1642, 'PBW')
# (1643, 'PCEF')
# (1644, 'PCY')
# (1645, 'PDEC')
# (1646, 'PDN')
# (1647, 'PEJ')
# (1648, 'PEX')
# (1649, 'PEXL')
# (1650, 'PFEB')
# (1651, 'PFFA')
# (1652, 'PFFD')
# (1653, 'PFFR')
# (1654, 'PFFV')
# (1655, 'PFIG')
# (1656, 'PFLD')
# (1657, 'PFXF')
# (1658, 'PGAL')
# (1659, 'PGF')
# (1660, 'PGHY')
# (1661, 'PGX')
# (1662, 'PHB')
# (1663, 'PHDG')
# (1664, 'PHYL')
# (1665, 'PHYS')
# (1666, 'PICB')
# (1667, 'PICK')
# (1668, 'PIFI')
# (1669, 'PILL')
# (1670, 'PIN')
# (1671, 'PJAN')
# (1672, 'PJP')
# (1673, 'PJUL')
# (1674, 'PJUN')
# (1675, 'PKB')
# (1676, 'PLAT')
# (1677, 'PLTM')
# (1678, 'PMAR')
# (1679, 'PMAY')
# (1680, 'PNOV')
# (1681, 'POCT')
# (1682, 'PPA')
# (1683, 'PPLT')
# (1684, 'PPTY')
# (1685, 'PQDI')
# (1686, 'PQIN')
# (1687, 'PQLC')
# (1688, 'PQSG')
# (1689, 'PQSV')
# (1690, 'PREF')
# (1691, 'PRF')
# (1692, 'PRNT')
# (1693, 'PSCX')
# (1694, 'PSEP')
# (1695, 'PSFD')
# (1696, 'PSFF')
# (1697, 'PSI')
# (1698, 'PSJ')
# (1699, 'PSK')
# (1700, 'PSLV')
# (1701, 'PSMB')
# (1702, 'PSMC')
# (1703, 'PSMD')
# (1704, 'PSMG')
# (1705, 'PSMM')
# (1706, 'PSP')
# (1707, 'PSQ')
# (1708, 'PSR')
# (1709, 'PST')
# (1710, 'PTBD')
# (1711, 'PTEU')
# (1712, 'PTIN')
# (1713, 'PTLC')
# (1714, 'PTMC')
# (1715, 'PTNQ')
# (1716, 'PULS')
# (1717, 'PUTW')
# (1718, 'PVI')
# (1719, 'PWB')
# (1720, 'PWC')
# (1721, 'PWS')
# (1722, 'PWV')
# (1723, 'PWZ')
# (1724, 'PXE')
# (1725, 'PXF')
# (1726, 'PXH')
# (1727, 'PXJ')
# (1728, 'PXQ')
# (1729, 'PZA')
# (1730, 'PZD')
# (1731, 'PZT')
# (1732, 'QAI')
# (1733, 'QARP')
# (1734, 'QDEC')
# (1735, 'QDEF')
# (1736, 'QDF')
# (1737, 'QDIV')
# (1738, 'QDYN')
# (1739, 'QED')
# (1740, 'QEFA')
# (1741, 'QEMM')
# (1742, 'QGRO')
# (1743, 'QID')
# (1744, 'QINT')
# (1745, 'QLC')
# (1746, 'QLD')
# (1747, 'QLS')
# (1748, 'QLTA')
# (1749, 'QLV')
# (1750, 'QLVD')
# (1751, 'QLVE')
# (1752, 'QMJ')
# (1753, 'QMN')
# (1754, 'QMOM')
# (1755, 'QPT')
# (1756, 'QPX')
# (1757, 'QQH')
# (1758, 'QQQE')
# (1759, 'QRFT')
# (1760, 'QSY')
# (1761, 'QTUM')
# (1762, 'QUAL')
# (1763, 'QULL')
# (1764, 'QUS')
# (1765, 'QVAL')
# (1766, 'QWLD')
# (1767, 'RAAX')
# (1768, 'RAFE')
# (1769, 'RALS')
# (1770, 'RAVI')
# (1771, 'RAYC')
# (1772, 'RBIN')
# (1773, 'RBND')
# (1774, 'RBUS')
# (1775, 'RCD')
# (1776, 'RDFI')
# (1777, 'RDIV')
# (1778, 'RDOG')
# (1779, 'REC')
# (1780, 'RECS')
# (1781, 'REET')
# (1782, 'REGL')
# (1783, 'REK')
# (1784, 'REM')
# (1785, 'REMX')
# (1786, 'RESD')
# (1787, 'RESE')
# (1788, 'RESP')
# (1789, 'RETL')
# (1790, 'REVS')
# (1791, 'REW')
# (1792, 'REZ')
# (1793, 'RFCI')
# (1794, 'RFDA')
# (1795, 'RFFC')
# (1796, 'RFG')
# (1797, 'RFUN')
# (1798, 'RFV')
# (1799, 'RGI')
# (1800, 'RHS')
# (1801, 'RIGS')
# (1802, 'RINF')
# (1803, 'RISN')
# (1804, 'RLY')
# (1805, 'ROAM')
# (1806, 'ROBO')
# (1807, 'RODE')
# (1808, 'RODM')
# (1809, 'ROKT')
# (1810, 'ROM')
# (1811, 'ROMO')
# (1812, 'ROOF')
# (1813, 'RORO')
# (1814, 'ROSC')
# (1815, 'ROUS')
# (1816, 'RPAR')
# (1817, 'RPG')
# (1818, 'RPV')
# (1819, 'RSP')
# (1820, 'RSX')
# (1821, 'RSXJ')
# (1822, 'RTAI')
# (1823, 'RTM')
# (1824, 'RUSL')
# (1825, 'RVNU')
# (1826, 'RVRS')
# (1827, 'RWGV')
# (1828, 'RWJ')
# (1829, 'RWK')
# (1830, 'RWL')
# (1831, 'RWM')
# (1832, 'RWO')
# (1833, 'RWR')
# (1834, 'RWVG')
# (1835, 'RWX')
# (1836, 'RXD')
# (1837, 'RXI')
# (1838, 'RXL')
# (1839, 'RYE')
# (1840, 'RYF')
# (1841, 'RYH')
# (1842, 'RYJ')
# (1843, 'RYLD')
# (1844, 'RYT')
# (1845, 'RYU')
# (1846, 'RZG')
# (1847, 'RZV')
# (1848, 'SAA')
# (1849, 'SBB')
# (1850, 'SBIO')
# (1851, 'SBM')
# (1852, 'SBUG')
# (1853, 'SCC')
# (1854, 'SCDL')
# (1855, 'SCHA')
# (1856, 'SCHB')
# (1857, 'SCHC')
# (1858, 'SCHD')
# (1859, 'SCHE')
# (1860, 'SCHF')
# (1861, 'SCHG')
# (1862, 'SCHH')
# (1863, 'SCHI')
# (1864, 'SCHJ')
# (1865, 'SCHK')
# (1866, 'SCHM')
# (1867, 'SCHO')
# (1868, 'SCHP')
# (1869, 'SCHQ')
# (1870, 'SCHR')
# (1871, 'SCHV')
# (1872, 'SCHX')
# (1873, 'SCHZ')
# (1874, 'SCJ')
# (1875, 'SCO')
# (1876, 'SDCI')
# (1877, 'SDD')
# (1878, 'SDEF')
# (1879, 'SDEI')
# (1880, 'SDEM')
# (1881, 'SDGA')
# (1882, 'SDIV')
# (1883, 'SDOG')
# (1884, 'SDOW')
# (1885, 'SDP')
# (1886, 'SDS')
# (1887, 'SDY')
# (1888, 'SECT')
# (1889, 'SEF')
# (1890, 'SEIX')
# (1891, 'SENT')
# (1892, 'SEPZ')
# (1893, 'SFHY')
# (1894, 'SFIG')
# (1895, 'SFY')
# (1896, 'SFYF')
# (1897, 'SFYX')
# (1898, 'SGDJ')
# (1899, 'SGDM')
# (1900, 'SGOL')
# (1901, 'SGOV')
# (1902, 'SH')
# (1903, 'SHAG')
# (1904, 'SHE')
# (1905, 'SHM')
# (1906, 'SHYD')
# (1907, 'SHYG')
# (1908, 'SHYL')
# (1909, 'SIJ')
# (1910, 'SIL')
# (1911, 'SILJ')
# (1912, 'SIMS')
# (1913, 'SIVR')
# (1914, 'SIXA')
# (1915, 'SIXH')
# (1916, 'SIXL')
# (1917, 'SIXS')
# (1918, 'SIZE')
# (1919, 'SJB')
# (1920, 'SJNK')
# (1921, 'SKF')
# (1922, 'SLT')
# (1923, 'SLV')
# (1924, 'SLVP')
# (1925, 'SLX')
# (1926, 'SLY')
# (1927, 'SLYG')
# (1928, 'SLYV')
# (1929, 'SMB')
# (1930, 'SMDD')
# (1931, 'SMDV')
# (1932, 'SMDY')
# (1933, 'SMEZ')
# (1934, 'SMIN')
# (1935, 'SMLF')
# (1936, 'SMLV')
# (1937, 'SMMD')
# (1938, 'SMMU')
# (1939, 'SMMV')
# (1940, 'SMN')
# (1941, 'SMOG')
# (1942, 'SNPE')
# (1943, 'SOVB')
# (1944, 'SOXL')
# (1945, 'SOXS')
# (1946, 'SOYB')
# (1947, 'SPAB')
# (1948, 'SPAK')
# (1949, 'SPBO')
# (1950, 'SPCX')
# (1951, 'SPD')
# (1952, 'SPDN')
# (1953, 'SPDV')
# (1954, 'SPDW')
# (1955, 'SPEM')
# (1956, 'SPEU')
# (1957, 'SPFF')
# (1958, 'SPGM')
# (1959, 'SPGP')
# (1960, 'SPHB')
# (1961, 'SPHD')
# (1962, 'SPHQ')
# (1963, 'SPHY')
# (1964, 'SPIB')
# (1965, 'SPIP')
# (1966, 'SPLB')
# (1967, 'SPLG')
# (1968, 'SPLV')
# (1969, 'SPMB')
# (1970, 'SPMD')
# (1971, 'SPMO')
# (1972, 'SPMV')
# (1973, 'SPPP')
# (1974, 'SPRE')
# (1975, 'SPSB')
# (1976, 'SPSK')
# (1977, 'SPSM')
# (1978, 'SPTI')
# (1979, 'SPTL')
# (1980, 'SPTM')
# (1981, 'SPTS')
# (1982, 'SPUC')
# (1983, 'SPUS')
# (1984, 'SPUU')
# (1985, 'SPVM')
# (1986, 'SPVU')
# (1987, 'SPXB')
# (1988, 'SPXE')
# (1989, 'SPXL')
# (1990, 'SPXN')
# (1991, 'SPXS')
# (1992, 'SPXT')
# (1993, 'SPXU')
# (1994, 'SPXV')
# (1995, 'SPXZ')
# (1996, 'SPY')
# (1997, 'SPYC')
# (1998, 'SPYD')
# (1999, 'SPYG')
# (2000, 'SPYV')
# (2001, 'SPYX')
# (2002, 'SQEW')
# (2003, 'SRLN')
# (2004, 'SRS')
# (2005, 'SRTY')
# (2006, 'SRVR')
# (2007, 'SSG')
# (2008, 'SSLY')
# (2009, 'SSO')
# (2010, 'SSPY')
# (2011, 'SSUS')
# (2012, 'STIP')
# (2013, 'STLC')
# (2014, 'STLG')
# (2015, 'STLV')
# (2016, 'STMB')
# (2017, 'STOT')
# (2018, 'STPZ')
# (2019, 'STSB')
# (2020, 'SUB')
# (2021, 'SUBZ')
# (2022, 'SULR')
# (2023, 'SUSA')
# (2024, 'SVAL')
# (2025, 'SVXY')
# (2026, 'SWAN')
# (2027, 'SYE')
# (2028, 'SYG')
# (2029, 'SYLD')
# (2030, 'SYV')
# (2031, 'SZK')
# (2032, 'SZNE')
# (2033, 'TAAG')
# (2034, 'TACE')
# (2035, 'TADS')
# (2036, 'TAEQ')
# (2037, 'TAGS')
# (2038, 'TAIL')
# (2039, 'TAN')
# (2040, 'TAXF')
# (2041, 'TBF')
# (2042, 'TBJL')
# (2043, 'TBT')
# (2044, 'TBX')
# (2045, 'TCHP')
# (2046, 'TCTL')
# (2047, 'TDSA')
# (2048, 'TDSB')
# (2049, 'TDSC')
# (2050, 'TDSD')
# (2051, 'TDSE')
# (2052, 'TDTF')
# (2053, 'TDTT')
# (2054, 'TDV')
# (2055, 'TDVG')
# (2056, 'TECB')
# (2057, 'TECL')
# (2058, 'TECS')
# (2059, 'TEGS')
# (2060, 'TEQI')
# (2061, 'TERM')
# (2062, 'TFI')
# (2063, 'TFIV')
# (2064, 'TFJL')
# (2065, 'TFLO')
# (2066, 'TFLT')
# (2067, 'TGIF')
# (2068, 'TGRW')
# (2069, 'THCX')
# (2070, 'THD')
# (2071, 'THNQ')
# (2072, 'THY')
# (2073, 'TILT')
# (2074, 'TIP')
# (2075, 'TIPX')
# (2076, 'TIPZ')
# (2077, 'TLH')
# (2078, 'TLTD')
# (2079, 'TLTE')
# (2080, 'TMAT')
# (2081, 'TMDV')
# (2082, 'TMF')
# (2083, 'TMFC')
# (2084, 'TMV')
# (2085, 'TNA')
# (2086, 'TOK')
# (2087, 'TOKE')
# (2088, 'TOLZ')
# (2089, 'TOTL')
# (2090, 'TPAY')
# (2091, 'TPHD')
# (2092, 'TPIF')
# (2093, 'TPLC')
# (2094, 'TPOR')
# (2095, 'TPSC')
# (2096, 'TPYP')
# (2097, 'TRND')
# (2098, 'TRTY')
# (2099, 'TSJA')
# (2100, 'TSOC')
# (2101, 'TTAC')
# (2102, 'TTAI')
# (2103, 'TTT')
# (2104, 'TWM')
# (2105, 'TYD')
# (2106, 'TYO')
# (2107, 'TZA')
# (2108, 'UAPR')
# (2109, 'UAUG')
# (2110, 'UBR')
# (2111, 'UBT')
# (2112, 'UCC')
# (2113, 'UCO')
# (2114, 'UCON')
# (2115, 'UDEC')
# (2116, 'UDN')
# (2117, 'UDOW')
# (2118, 'UEVM')
# (2119, 'UFEB')
# (2120, 'UGA')
# (2121, 'UGE')
# (2122, 'UGL')
# (2123, 'UITB')
# (2124, 'UIVM')
# (2125, 'UJAN')
# (2126, 'UJB')
# (2127, 'UJUL')
# (2128, 'UJUN')
# (2129, 'ULE')
# (2130, 'ULST')
# (2131, 'ULTR')
# (2132, 'ULVM')
# (2133, 'UMAR')
# (2134, 'UMAY')
# (2135, 'UMDD')
# (2136, 'UNG')
# (2137, 'UNL')
# (2138, 'UNOV')
# (2139, 'UOCT')
# (2140, 'UPRO')
# (2141, 'UPV')
# (2142, 'UPW')
# (2143, 'URA')
# (2144, 'URE')
# (2145, 'URNM')
# (2146, 'URTH')
# (2147, 'URTY')
# (2148, 'USAI')
# (2149, 'USCI')
# (2150, 'USD')
# (2151, 'USDU')
# (2152, 'USEP')
# (2153, 'USEQ')
# (2154, 'USFR')
# (2155, 'USHG')
# (2156, 'USHY')
# (2157, 'USI')
# (2158, 'USL')
# (2159, 'USMF')
# (2160, 'USML')
# (2161, 'USMV')
# (2162, 'USO')
# (2163, 'USRT')
# (2164, 'USSG')
# (2165, 'UST')
# (2166, 'USTB')
# (2167, 'USVM')
# (2168, 'UTES')
# (2169, 'UTRN')
# (2170, 'UTSL')
# (2171, 'UUP')
# (2172, 'UVXY')
# (2173, 'UWM')
# (2174, 'UXI')
# (2175, 'UYG')
# (2176, 'UYM')
# (2177, 'VABS')
# (2178, 'VALQ')
# (2179, 'VALT')
# (2180, 'VAMO')
# (2181, 'VAW')
# (2182, 'VB')
# (2183, 'VBK')
# (2184, 'VBND')
# (2185, 'VBR')
# (2186, 'VCAR')
# (2187, 'VCEB')
# (2188, 'VCLO')
# (2189, 'VCR')
# (2190, 'VDC')
# (2191, 'VDE')
# (2192, 'VEA')
# (2193, 'VEGA')
# (2194, 'VEGI')
# (2195, 'VEGN')
# (2196, 'VEU')
# (2197, 'VFH')
# (2198, 'VFIN')
# (2199, 'VFLQ')
# (2200, 'VFMF')
# (2201, 'VFMO')
# (2202, 'VFMV')
# (2203, 'VFQY')
# (2204, 'VFVA')
# (2205, 'VGK')
# (2206, 'VGT')
# (2207, 'VHT')
# (2208, 'VICE')
# (2209, 'VIDI')
# (2210, 'VIG')
# (2211, 'VIOG')
# (2212, 'VIOO')
# (2213, 'VIOV')
# (2214, 'VIRS')
# (2215, 'VIS')
# (2216, 'VIXM')
# (2217, 'VIXY')
# (2218, 'VLU')
# (2219, 'VLUE')
# (2220, 'VMOT')
# (2221, 'VNLA')
# (2222, 'VNM')
# (2223, 'VNMC')
# (2224, 'VNQ')
# (2225, 'VNSE')
# (2226, 'VO')
# (2227, 'VOE')
# (2228, 'VOO')
# (2229, 'VOOG')
# (2230, 'VOOV')
# (2231, 'VOT')
# (2232, 'VOX')
# (2233, 'VPC')
# (2234, 'VPL')
# (2235, 'VPOP')
# (2236, 'VPU')
# (2237, 'VRAI')
# (2238, 'VRP')
# (2239, 'VSGX')
# (2240, 'VSL')
# (2241, 'VSS')
# (2242, 'VT')
# (2243, 'VTEB')
# (2244, 'VTI')
# (2245, 'VTV')
# (2246, 'VUG')
# (2247, 'VUSE')
# (2248, 'VV')
# (2249, 'VWID')
# (2250, 'VWO')
# (2251, 'VXF')
# (2252, 'VYM')
# (2253, 'WANT')
# (2254, 'WBIE')
# (2255, 'WBIF')
# (2256, 'WBIG')
# (2257, 'WBII')
# (2258, 'WBIL')
# (2259, 'WBIN')
# (2260, 'WBIT')
# (2261, 'WBIY')
# (2262, 'WDIV')
# (2263, 'WEAT')
# (2264, 'WEBL')
# (2265, 'WEBS')
# (2266, 'WFH')
# (2267, 'WFHY')
# (2268, 'WFIG')
# (2269, 'WIP')
# (2270, 'WIZ')
# (2271, 'WLDR')
# (2272, 'WOMN')
# (2273, 'WPS')
# (2274, 'WTMF')
# (2275, 'WUGI')
# (2276, 'WWJD')
# (2277, 'WWOW')
# (2278, 'XAR')
# (2279, 'XBI')
# (2280, 'XBUY')
# (2281, 'XCEM')
# (2282, 'XDAT')
# (2283, 'XDIV')
# (2284, 'XES')
# (2285, 'XHB')
# (2286, 'XHE')
# (2287, 'XHS')
# (2288, 'XITK')
# (2289, 'XJH')
# (2290, 'XJR')
# (2291, 'XLB')
# (2292, 'XLC')
# (2293, 'XLE')
# (2294, 'XLF')
# (2295, 'XLG')
# (2296, 'XLI')
# (2297, 'XLK')
# (2298, 'XLP')
# (2299, 'XLRE')
# (2300, 'XLSR')
# (2301, 'XLU')
# (2302, 'XLV')
# (2303, 'XLY')
# (2304, 'XME')
# (2305, 'XMHQ')
# (2306, 'XMLV')
# (2307, 'XMMO')
# (2308, 'XMPT')
# (2309, 'XMVM')
# (2310, 'XNTK')
# (2311, 'XOP')
# (2312, 'XOUT')
# (2313, 'XPH')
# (2314, 'XPP')
# (2315, 'XRLV')
# (2316, 'XRT')
# (2317, 'XSD')
# (2318, 'XSHD')
# (2319, 'XSHQ')
# (2320, 'XSLV')
# (2321, 'XSMO')
# (2322, 'XSOE')
# (2323, 'XSVM')
# (2324, 'XSW')
# (2325, 'XTL')
# (2326, 'XTN')
# (2327, 'XVV')
# (2328, 'XWEB')
# (2329, 'XYLD')
# (2330, 'XYLG')
# (2331, 'YANG')
# (2332, 'YCL')
# (2333, 'YCS')
# (2334, 'YDEC')
# (2335, 'YINN')
# (2336, 'YLD')
# (2337, 'YOLO')
# (2338, 'YXI')
# (2339, 'YYY')
# (2340, 'ZCAN')
# (2341, 'ZDEU')
# (2342, 'ZGBR')
# (2343, 'ZHOK')
# (2344, 'ZIG')
# (2345, 'ZJPN')
# (2346, 'ZROZ')
# (2347, 'ZSL')

# %% [markdown]
# 다운받은 데이터 중 가장 긴 기간을 가지는 SPY ETF 데이터가 잘 들어왔습니다.

# %%
start = '1993-01-22'
end = '2021-02-19'

con = sqlite3.connect('USListedETFPrice.db')
read_SPY = pd.read_sql("select * from 'SPY' ", con, index_col='Date')
read_SPY
# Out:
#                            High         Low        Open       Close  \
# Date
# 1993-01-29 00:00:00   43.968750   43.750000   43.968750   43.937500
# 1993-02-01 00:00:00   44.250000   43.968750   43.968750   44.250000
# 1993-02-02 00:00:00   44.375000   44.125000   44.218750   44.343750
# 1993-02-03 00:00:00   44.843750   44.375000   44.406250   44.812500
# 1993-02-04 00:00:00   45.093750   44.468750   44.968750   45.000000
# ...                         ...         ...         ...         ...
# 2021-02-12 00:00:00  392.899994  389.769989  389.850006  392.640015
# 2021-02-16 00:00:00  394.170013  391.529999  393.959991  392.299988
# 2021-02-17 00:00:00  392.660004  389.329987  390.420013  392.390015
# 2021-02-18 00:00:00  391.519989  387.739990  389.589996  390.720001
# 2021-02-19 00:00:00  392.380005  389.549988  392.070007  390.029999
#
#                          Volume   Adj Close
# Date
# 1993-01-29 00:00:00   1003200.0   25.968958
# 1993-02-01 00:00:00    480500.0   26.153660
# 1993-02-02 00:00:00    201300.0   26.209057
# 1993-02-03 00:00:00    529400.0   26.486113
# 1993-02-04 00:00:00    531500.0   26.596937
# ...                         ...         ...
# 2021-02-12 00:00:00  50593300.0  392.640015
# 2021-02-16 00:00:00  50972400.0  392.299988
# 2021-02-17 00:00:00  52290600.0  392.390015
# 2021-02-18 00:00:00  59712800.0  390.720001
# 2021-02-19 00:00:00  83142800.0  390.029999
#
# [7066 rows x 6 columns]

# %%
con.close()
